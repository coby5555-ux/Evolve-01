# %% [markdown]
# ## 🧾 Ejercicios `while` con contexto de negocio
#
# ---
#
# ### 1️⃣ Calcular el total de ventas del día
#
# #### Objetivo:
# Un comercio registra sus ventas una a una. El programa debe permitir al usuario ingresar el valor de cada venta.
# El proceso termina cuando se introduce un valor de venta igual a `0`. Al final, se muestra el total acumulado.

# %%
total_ventas = 0

venta = 1

while venta != 0:
    venta = float(input("Valor de la venta (0 para finalizar): "))
    if venta >1:
        total_ventas += venta

print(f"Total de ventas: {total_ventas}")
# Out:
# Total de ventas: 103.0

# %% [markdown]
# ### 2️⃣ Registrar pagos hasta alcanzar una meta
#
# #### Objetivo:
# Una tienda necesita recaudar al menos **500 euros** en el día.
# Cada cliente paga una cantidad y se va sumando al total.
# El programa debe seguir pidiendo montos hasta que se alcance (o supere) la meta.
# Al final, muestra cuánto se recaudó y cuántos pagos fueron necesarios.

# %%
total_recaudado = 0
pagos = 0
meta = 500

while total_recaudado < meta:
    dineros = float(input("¿Cuanto vas a pagar?"))
    if dineros > 0:
        total_recaudado += dineros
        pagos += 1
    elif dineros < 0:
        print("Pago negativo... Estafa")
    else:
        print("Este cliente no quiere pagar")

print(f"Total recaudado de: {total_recaudado} euros, con un total de {pagos} pagos.")
# Out:
# Este cliente no quiere pagar
# Pago negativo... Estafa
# Total recaudado de: 1100.0 euros, con un total de 2 pagos.

# %% [markdown]
# ### 3️⃣ Control de stock de productos
# ##### Objetivo:
# Un sistema de inventario debe restar unidades del stock cada vez que hay una venta.
# El stock inicial es 20. En cada iteración, se ingresa cuántas unidades se vendieron.
# El bucle se detiene cuando no queda stock suficiente para cubrir la venta.

# %%
stock = 20

while stock > 0:
    venta = int(input("¿Cuántas unidades quieres comprar? "))
    if venta > stock:
        print(f"Lo siento, solo quedan {stock} unidades en stock.")
    elif venta > 0:
        stock -= venta
        print(f"Has comprado {venta} unidades. Quedan {stock} unidades en stock.")
    else:
        print("Cantidad no válida. Por favor, ingresa un número positivo.")

print("¡Stock agotado! No se pueden realizar más ventas.")
# Out:
# Cantidad no válida. Por favor, ingresa un número positivo.
# Lo siento, solo quedan 20 unidades en stock.
# Has comprado 20 unidades. Quedan 0 unidades en stock.
# ¡Stock agotado! No se pueden realizar más ventas.

# %% [markdown]
# ### 4️⃣ Registrar empleados hasta llegar al límite
# ##### Objetivo:
# Una empresa va registrando empleados nuevos. El sistema pide el nombre de cada uno.
# Solo se pueden registrar hasta 10 empleados. Cuando se llega a ese número, se detiene el registro y se imprime cuántos se registraron en total.

# %%
empleados_registrados = 0

while empleados_registrados < 10:
    nombre = input("Ingrese el nombre del empleado (o 'salir' para finalizar): ")
    if nombre.lower() == 'salir':
        break
    empleados_registrados += 1
    print(f"Empleado '{nombre}' registrado. Total de empleados registrados: {empleados_registrados}")
# Out:
# Empleado 'asd' registrado. Total de empleados registrados: 1
# Empleado 'filipo' registrado. Total de empleados registrados: 2
# Empleado 'evaristo' registrado. Total de empleados registrados: 3
# Empleado 'nostre vincent' registrado. Total de empleados registrados: 4
# Empleado 'fgsdfg' registrado. Total de empleados registrados: 5
# Empleado 'dasfasf' registrado. Total de empleados registrados: 6
# Empleado 'sadcx' registrado. Total de empleados registrados: 7
# Empleado 'wqe' registrado. Total de empleados registrados: 8
# Empleado 'fxcv' registrado. Total de empleados registrados: 9
# Empleado 'sadf' registrado. Total de empleados registrados: 10
