# %% [markdown]
# # Título Principal (H1)
# ## Subtítulo (H2)
#
# Podemos escribir texto normal para explicar nuestros hallazgos.
# * También
# * Podemos
# * Hacer listas
#
# **Texto en negrita** y *texto en cursiva*.

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hola mundo!")
# Out:
# Hola mundo!
